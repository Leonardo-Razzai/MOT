# %%
from MOTLib.AnMOT import *

# %%
D_L = 1042 # MHz
B = 8 # A
DATE = './'

BN_vals = (#999.5, 1002, 1004.5, 1007, 1009.5,1012, 1014.5,
          1017, 1019.5,
          1022, 1024.5, 1026, 1028.5,
          1031, 1033.5, 1036, 1038.5,
          1041, 1042.5, 1045, 1047.5, 1050) # MHz

DataSet = MOTdata_Lorentzian(DATE, B=B, BN_vals=BN_vals, BN_L=D_L)

# %%
DataSet.ImportData()
# Out:
# Offset = 0.090 V

# %%
DataSet.PlotRawData()

# %%
DataSet.PlotRawData_zoom(tmin=4.8, tmax=5.2)

# %% [markdown]
# ## Select data

# %%
DataSet.SelectData(plot=True, tmin=4.8, tmax=5.2)

# %% [markdown]
# ## Fit Lorentzian

# %%
DataSet.FitLorentzian(plot=True)

# %% [markdown]
# ## Save Lorentzian Parmeters and fluorescence data

# %%
DataSet.SaveData()
DataSet.SaveParameters()

# %% [markdown]
# ## Calculate the number of atoms captured if Cooler beat-note is D_L while loading

# %%
DataSet.CalculateNumOfAtoms()
# Out:
# Number of atoms = (0.42 ± 0.08) * 10^8
