# %%
from AnMOT import *

# %%
D_L = 1036 # MHz
B = 6 # A
DATE = './2024-12-18/'

min_BN = 1023 # MHz
max_BN = 1049 # MHz
step = 2 # MHz

BN_vals = np.arange(min_BN, max_BN + step, step) # MHz
DataSet = MOTdata_Lorentzian(DATE, B=B, BN_vals=BN_vals, BN_L=D_L)

# %%
DataSet.ImportData()
# Out:
# Offset = 0.099 V

# %%
DataSet.PlotRawData()

# %%
DataSet.PlotRawData_zoom(tmin=4.3, tmax=4.5)

# %% [markdown]
# ## Select data

# %%
DataSet.SelectData(plot=True, tmin=4.3, tmax=4.5)

# %% [markdown]
# ## Fit Lorentzian

# %%
DataSet.FitLorentzian(plot=True)

# %% [markdown]
# ## Save Lorentzian Parmeters and fluorescence data

# %%
DataSet.SaveData()
DataSet.SaveParameters()

# %% [markdown]
# ## Calculate the number of atoms captured if Cooler beat-note is D_L while loading

# %%
DataSet.CalculateNumOfAtoms()
# Out:
# Number of atoms = (0.47 ± 0.03) * 10^8
