# %%
from AnMOT import *

# %%
D_L = 1036 # MHz
B = 5 # A
DATE = './2024-12-18/'

BN_vals =  range(1025, 1050, 2) # MHz
DataSetB_5 = MOTdata(DATE, B=5, BN_vals, D_L=D_L)

# %%
DataSetB_5.ImportData()

# %%
DataSetB_5.PlotRawData()

# %%
DataSetB_5.PlotRawData_zoom()

# %% [markdown]
# ## Select data

# %%
DataSetB_5.SelectData(plot=True)

# %% [markdown]
# ## Fit Lorentzian

# %%
DataSetB_5.FitLorentzian(plot=True)

# %% [markdown]
# ## Calculate the number of atoms captured if Cooler beat-note is D_L while loading

# %%
DataSetB_5.CalculateNumOfAtoms()
# Out:
# Number of atoms = (1.83e+00 ± 1.42e-01) * 10^7
