# %%
from AnMOT import *

# %%
D_L = 1036 # MHz
B = 7 # A
DATE = './2024-12-18/'

BN_vals = range(1025, 1050, 2) # MHz
DataSet = MOTdata(DATE, B=B, BN_vals=BN_vals, BN_L=D_L)

# %%
DataSet.ImportData()

# %%
DataSet.PlotRawData()

# %%
DataSet.PlotRawData_zoom(tmin=4.3, tmax=4.4)

# %% [markdown]
# ## Select data

# %%
DataSet.SelectData(plot=True, tmin=4.3, tmax=4.4)

# %% [markdown]
# ## Fit Lorentzian

# %%
DataSet.FitLorentzian(plot=True)

# %% [markdown]
# ## Save Lorentzian Parmeters and fluorescence data

# %%
DataSet.SaveData()
DataSet.SaveParameters()

# %% [markdown]
# ## Calculate the number of atoms captured if Cooler beat-note is D_L while loading

# %%
DataSet.CalculateNumOfAtoms()
# Out:
# Number of atoms = (1.79 ± 0.14) * 10^7
