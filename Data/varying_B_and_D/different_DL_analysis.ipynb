# %%
from AnMOT import *

# %%
D_res = 1027 # MHz
B = 10 # A
DATE = './2025-01-16/'

BN_L_vals = range(1034, 1050, 2) # MHz
DataSet = MOTdata_Loading(DATE, B=B, BN_L_vals=BN_L_vals, BN_res=D_res)

# %%
DataSet.ImportData()

# %%
DataSet.PlotRawData()

# %%
DataSet.PlotRawData_zoom(tmin=4.9, tmax=5.2)

# %%
DataSet.SelectData(tmin=4.9, tmax=5.2, N_conv=4, plot=True)

# %%
DataSet.Plot_maxima_fluorescence()

# %%
DataSet.SaveData_fluorescence()

# %%
DataSet.ERRORS
# Out:
# [np.float64(0.0007930596104264715),
#  np.float64(0.0007437229200948035),
#  np.float64(0.0007796931609686322),
#  np.float64(0.0007640073160253772),
#  np.float64(0.000752617476180893),
#  np.float64(0.0007853421180577374),
#  np.float64(0.0008288290613374614),
#  np.float64(0.0007782887398586736)]
