# %%
from MOTLib.AnMOT import *

# %%
D_res = 1027 # MHz
B = 8 # A
DATE = './2025-01-16/'

BN_L_vals = range(1032, 1046, 2) # MHz
DataSet = MOTdata_Loading(DATE, B=B, BN_L_vals=BN_L_vals, BN_res=D_res)

# %%
DataSet.ImportData()
# Out:
# Offset = 0.049 V

# %%
DataSet.PlotRawData()

# %%
DataSet.PlotRawData_zoom(tmin=0.9, tmax=2.5)

# %%
DataSet.SelectData_Peaks(tmin=4.9, tmax=5.2, N_conv=4, plot=True)

# %%
DataSet.Plot_maxima_fluorescence()

# %%
DataSet.SaveData_fluorescence()

# %%
DataSet.Fit_Load(tmin=0.7, tmax=4.0, N_conv=8, plot=True)
# Out:
# x_start = 1.111 s
#
#  VL = (0.0097 ± 0.0000) V
#  tau = (0.2592 ± 0.0009) s
#  velocity capture = 0.0375 ± 0.0001 V/s
# x_start = 1.042 s
#
#  VL = (0.0168 ± 0.0000) V
#  tau = (0.3416 ± 0.0007) s
#  velocity capture = 0.0491 ± 0.0001 V/s
# x_start = 1.012 s
#
#  VL = (0.0209 ± 0.0000) V
#  tau = (0.4001 ± 0.0007) s
#  velocity capture = 0.0522 ± 0.0001 V/s
# x_start = 1.089 s
#
#  VL = (0.0209 ± 0.0000) V
#  tau = (0.4200 ± 0.0008) s
#  velocity capture = 0.0497 ± 0.0001 V/s
# x_start = 1.076 s
#
#  VL = (0.0205 ± 0.0000) V
#  tau = (0.4892 ± 0.0010) s
#  velocity capture = 0.0420 ± 0.0001 V/s
# x_start = 0.987 s
#
#  VL = (0.0164 ± 0.0000) V
#  tau = (0.4057 ± 0.0013) s
#  velocity capture = 0.0404 ± 0.0001 V/s
# x_start = 1.099 s
#
#  VL = (0.0136 ± 0.0000) V
#  tau = (0.5737 ± 0.0036) s
#  velocity capture = 0.0237 ± 0.0002 V/s

# %%
DataSet.SaveParameters_Load()
