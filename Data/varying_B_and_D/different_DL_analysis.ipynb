# %%
from AnMOT import *

# %%
D_res = 1027 # MHz
B = 11 # A
DATE = './2025-01-16/'

BN_L_vals = range(1034, 1050, 2) # MHz
DataSet = MOTdata_Loading(DATE, B=B, BN_L_vals=BN_L_vals, BN_res=D_res)

# %%
DataSet.ImportData()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 DataSet.ImportData()
#
# File c:\Users\User\OneDrive - Alma Mater Studiorum Università di Bologna\Desktop\Files_desktop\Bologna\PhD\MOT\Data\varying_B_and_D\AnMOT.py:500, in MOTdata_Loading.ImportData(self)
#     498 for i, D in enumerate(self.BN_L_vals):
#     499     file_list = list(directory.glob(f"B={self.B}_D={D}.csv"))
# --> 500     df = pd.read_csv(file_list[0], header=1, names=['Time [s]', 'Sig [V]'])
#     502     x_data = df['Time [s]'].to_numpy()
#     503     x_data = x_data - np.min(x_data)
#
# IndexError: list index out of range

# %%
DataSet.PlotRawData()

# %%
DataSet.PlotRawData_zoom(tmin=4.9, tmax=5.1)

# %%
DataSet.SelectData(tmin=4.9, tmax=5.1, plot=True)

# %%
DataSet.Plot_maxima_fluorescence()

# %%
DataSet.SaveData_fluorescence()
