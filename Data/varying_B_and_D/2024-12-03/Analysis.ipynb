# %%
from MOTLib.AnMOT import *

# %%
D_L = 1037 # MHz
B =5 # A
DATE = './'

BN_vals = (#1014, 1017,1020,
          1023, 1026, 1029,
          1032, 1035, 1038,
          1041, 1044, 1047, 1050) # MHz

DataSet = MOTdata_Lorentzian(DATE, B=B, BN_vals=BN_vals, BN_L=D_L)

# %%
DataSet.ImportData()
# Out:
# Offset = 0.054 V

# %%
DataSet.PlotRawData()

# %%
DataSet.PlotRawData_zoom(tmin=3.8, tmax=4.2)

# %% [markdown]
# ## Select data

# %%
DataSet.SelectData(plot=True, tmin=3.8, tmax=4.2)

# %% [markdown]
# ## Fit Lorentzian

# %%
DataSet.FitLorentzian(plot=True)

# %% [markdown]
# ## Save Lorentzian Parmeters and fluorescence data

# %%
DataSet.SaveData()
DataSet.SaveParameters()

# %% [markdown]
# ## Calculate the number of atoms captured if Cooler beat-note is D_L while loading

# %%
DataSet.CalculateNumOfAtoms()
# Out:
# Number of atoms = (0.27 ± 0.05) * 10^8
